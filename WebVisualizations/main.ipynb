# %% [markdown]
# # Data Viz Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import csv to data frame
df = pd.read_csv('../Resources/cities.csv')

# %%
# Look at head
df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
# Declare variables for data analysis
latitude = df['Lat']
cloudiness = df['Cloudiness']
humidity = df['Humidity']
max_temp = df['Max Temp']
wind_speed = df['Wind Speed']

# %% [markdown]
# ## Latitude vs Max Temp

# %%
plt.scatter(latitude, max_temp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig('../Resources/assets/images/lat_v_maxt.png')
plt.show()

# %% [markdown]
# ## Latitude vs Humidity

# %%
plt.scatter(latitude, humidity)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig('../Resources/assets/images/lat_v_humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs Cloudiness

# %%
plt.scatter(latitude, cloudiness)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig('../Resources/assets/images/lat_v_cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs Wind Speed

# %%
plt.scatter(latitude, wind_speed)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig('../Resources/assets/images/lat_v_winds.png')
plt.show()

# %%
df.to_html('../Resources/assets/cities.html', index = False)
